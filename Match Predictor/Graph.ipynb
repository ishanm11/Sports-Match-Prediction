# %%
import pandas as pd
import csv
import sys

# %%
df = pd.read_csv("ultra.csv", index_col=0)

# %%
df.head()
# Out:
#    actual_x  predicted_x        date   team_x      opponent_x result_x  \
# 0         0            0  2022-09-04  Arsenal  Manchester Utd        L
# 1         1            1  2022-09-18  Arsenal       Brentford        W
# 2         1            1  2022-10-01  Arsenal       Tottenham        W
# 3         1            1  2022-10-09  Arsenal       Liverpool        W
# 4         1            1  2022-10-16  Arsenal    Leeds United        W
#
#   new_team_x  actual_y  predicted_y             team_y opponent_y result_y  \
# 0    Arsenal         1            1  Manchester United    Arsenal        W
# 1    Arsenal         0            0          Brentford    Arsenal        L
# 2    Arsenal         0            0  Tottenham Hotspur    Arsenal        L
# 3    Arsenal         0            0          Liverpool    Arsenal        L
# 4    Arsenal         0            0       Leeds United    Arsenal        L
#
#        new_team_y
# 0  Manchester Utd
# 1       Brentford
# 2       Tottenham
# ...

# %%
team = input("Enter your favourite team: ")
team
df1 = df[df['team_x'] == team]
df1
# Out:
# Enter your favourite team:  Arsenal
#    actual_x  predicted_x        date   team_x       opponent_x result_x  \
# 0         0            0  2022-09-04  Arsenal   Manchester Utd        L
# 1         1            1  2022-09-18  Arsenal        Brentford        W
# 2         1            1  2022-10-01  Arsenal        Tottenham        W
# 3         1            1  2022-10-09  Arsenal        Liverpool        W
# 4         1            1  2022-10-16  Arsenal     Leeds United        W
# 5         0            0  2022-10-23  Arsenal      Southampton        D
# 6         1            1  2022-10-30  Arsenal  Nott'ham Forest        W
#
#   new_team_x  actual_y  predicted_y             team_y opponent_y result_y  \
# 0    Arsenal         1            1  Manchester United    Arsenal        W
# 1    Arsenal         0            0          Brentford    Arsenal        L
# 2    Arsenal         0            0  Tottenham Hotspur    Arsenal        L
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df1['date'], df1['opponent_x'])
plt.show()

# %%
plt.plot(df1['date'],df1['team_y'])
plt.show()

# %%
a = df['actual_y']
b = df['predicted_y']
plt.bar(a,b, color = "red",width = 0.5)
plt.title(" Team Y")
plt.xlabel("actual y")
plt.ylabel("predicted y")

plt.show()
